# %%
import numpy as np
import random
import infomap
import networkx as nx
import re
import pandas as pd
from sklearn.metrics.cluster import adjusted_mutual_info_score as ami
import sys

# %%
# %reload_ext autoreload
# %autoreload 2
from src import main

# %%
main.run_all_test_32()
# Out:
# run_regularized_infomap_test_32()...
# ...
# Read state network from file 'output/network_N32_om1_nc8_E3000_mu10_sample1.net'...
# Parsed network: DiGraph with 224 nodes and 1165 edges
# Found 4 modules with codelength 3.206988232166987
#
# Found 4 modules with codelength=3.207 and ami=1.000
# Read state network from file 'output/network_N32_om2_nc8_E3000_mu10_sample1.net'...
# Parsed network: DiGraph with 414 nodes and 1877 edges
# Found 8 modules with codelength 3.950760545385063
#
# Found 8 modules with codelength=3.951 and ami=1.000
# Read state network from file 'output/network_N32_om3_nc8_E3000_mu10_sample1.net'...
# Parsed network: DiGraph with 562 nodes and 2049 edges
# Found 12 modules with codelength 4.137895638987561
#
# Found 12 modules with codelength=4.138 and ami=1.000
# Read state network from file 'output/network_N32_om4_nc8_E3000_mu10_sample1.net'...
# Parsed network: DiGraph with 668 nodes and 2092 edges
# Found 16 modules with codelength 4.296297374441888
#
# ...

# %%
main.run_posterior_unconstrained_infomap_test_128()
# Out:
# Skip generate synthetic data for _N128_om1_nc32_E25000_mu10_sample1
# Skip generate posterior 2b network output/posterior_unconstrained_network_N128_om1_nc32_E25000_mu10_sample1.net from output/network_N128_om1_nc32_E25000_mu10_sample1.net
# Skip generate synthetic data for _N128_om2_nc32_E25000_mu10_sample1
# Skip generate posterior 2b network output/posterior_unconstrained_network_N128_om2_nc32_E25000_mu10_sample1.net from output/network_N128_om2_nc32_E25000_mu10_sample1.net
# Skip generate synthetic data for _N128_om3_nc32_E25000_mu10_sample1
# Skip generate synthetic data for _N128_om4_nc32_E25000_mu10_sample1
# Skip generate synthetic data for _N128_om5_nc32_E25000_mu10_sample1
# Skip generate synthetic data for _N128_om6_nc32_E25000_mu10_sample1
# Skip generate synthetic data for _N128_om7_nc32_E25000_mu10_sample1
# Skip generate synthetic data for _N128_om8_nc32_E25000_mu10_sample1

# %%
main.run_all_test_128()
# Out:
# Skip generate synthetic data for _N128_om1_nc32_E25000_mu10_sample1
# Read state network from file 'output/network_N128_om1_nc32_E25000_mu10_sample1.net'...
# Parsed network: DiGraph with 3968 nodes and 20454 edges
# Found 4 modules with codelength 5.127448222919763
#
# Found 4 modules with codelength=5.127 and ami=1.000
# Skip generate synthetic data for _N128_om2_nc32_E25000_mu10_sample1
# Read state network from file 'output/network_N128_om2_nc32_E25000_mu10_sample1.net'...
# Parsed network: DiGraph with 7284 nodes and 23795 edges
# Found 8 modules with codelength 6.0377188607655805
#
# Found 8 modules with codelength=6.038 and ami=1.000
# Skip generate synthetic data for _N128_om3_nc32_E25000_mu10_sample1
# Read state network from file 'output/network_N128_om3_nc32_E25000_mu10_sample1.net'...
# Parsed network: DiGraph with 9561 nodes and 24006 edges
# Found 12 modules with codelength 6.373404480810435
#
# Found 12 modules with codelength=6.373 and ami=1.000
# ...

# %%
    # for om in range(2,9):
    #     N=128
    #     nc=32
    #     E=25000
    #     mu=0.1
    #     r=1
    #     suffix = main.get_suffix(N, om, nc, E, mu, r)

    #     result = pd.read_csv(f"output/infomap_partition_{suffix}_posterior_unconstrained.tsv", sep="\t")
        
    #     # 4. Calculate AMI
    #     ref = pd.read_csv(main.get_planted_partition_filename(N, om, nc, E, mu, r), sep=" ", names=["state_name", "state_id", "module_id"])
    #     ami = main.compute_ami(ref, result)

    #     print(ami)

# %%
main.plot_result(N=128, nc=32, E=25000, mu=0.1)

# %%
main.plot_result()

# %% [markdown]
# # Old result for N=32 network

# %%
main.plot_result()
